# %%
# %pip install pandas matplotlib scikit-learn seaborn ipympl scipy
import pandas as pd
# %matplotlib widget
#%matplotlib widget
#%matplotlib
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
import seaborn as sns
from itertools import combinations
from scipy.signal import savgol_filter
from scipy.sparse import diags
from scipy.linalg import solve
import scipy as sp
import scipy.fftpack
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Read each CSV file into separate DataFrames
df1 = pd.read_csv('lowpm.csv')  # Replace 'file1.csv' with your CSV file name/path
df2 = pd.read_csv('medpm.csv')  # Replace 'file2.csv' with your CSV file name/path
df3 = pd.read_csv('highpm.csv')  # Replace 'file3.csv' with your CSV file name/path

# Merge DataFrames horizontally
merged_df = pd.concat([df1, df2, df3], axis=1)
merged_df

print(merged_df)
# Out:
#      Low PM    Med PM   High PM
# 0  0.960661  0.748938  0.883252
# 1  0.958350  0.768886  0.899676
# 2  0.375300 -0.038310  0.985029
# 3  0.775468  0.672994  0.956565
# 4  0.251075  0.645051  0.971034

# %%
# Define a dictionary to map old index labels to new ones
new_index_names = {0: 'SPS30', 1: 'SEN55', 2: 'HPMA115', 3: 'NextPM', 4: 'SDS011'}

# Rename rows in the DataFrame
merged_df.rename(index=new_index_names, inplace=True)
merged_df
# Out:
#            Low PM    Med PM   High PM
# SPS30    0.960661  0.748938  0.883252
# SEN55    0.958350  0.768886  0.899676
# HPMA115  0.375300 -0.038310  0.985029
# NextPM   0.775468  0.672994  0.956565
# SDS011   0.251075  0.645051  0.971034

# %%
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.8) 
sns.heatmap(merged_df, annot=True,annot_kws={"size": 20}, cmap='viridis')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
